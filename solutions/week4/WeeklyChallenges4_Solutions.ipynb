# %% [markdown]
# # Challenges Week 4
#
# Now that you have some expereince with pandas and data exploration in Python, it's time for you to combine and apply this week's knowledge. You will start working on these challenges in the tutorial and will be asked to complete them by the end of the week.
#
# In each challange, you are asked to provide the programing solution to it as well as a technical interpretation explaining the steps taken and the result.
#
# Some important notes for the challenges:
#
# * If you get an error message, try to troubleshoot it (using Google often helps). If all else fails, go to the next excercise (but make sure to hand it in).
# * We will make sure to provide feedback and improvement suggestions in the rubric. Make sure to read them; they will help you improve next week.

# %% [markdown]
# # Challenge 1
#
# We will use the dataset marketing_campaign.csv. *Hint: you will need to specify the column separator to properly read the dataset. Have a look at lecture of week 3 to check how do it.*
#
# A full description of the dataset is available below.
#
# Customer Personality Analysis is a detailed analysis of a company’s ideal customers. It helps a business to better understand its customers and makes it easier for them to modify products according to the specific needs, behaviors and concerns of different types of customers.
#
# Customer personality analysis helps a business to modify its product based on its target customers from different types of customer segments. For example, instead of spending money to market a new product to every customer in the company’s database, a company can analyze which customer segment is most likely to buy the product and then market the product only on that particular segment.
#
# **People**
# <br>
# customer_id: Customer's unique identifier
# <br>
# Year_Birth: Customer's birth year
# <br>
# Education: Customer's education level
# <br>
# Marital_Status: Customer's marital status
# <br>
# Income: Customer's yearly household income
# <br>
# Kidhome: Number of children in customer's household
# <br>
# Teenhome: Number of teenagers in customer's household
# <br>
# Dt_Customer: Date of customer's enrollment with the company
# <br>
# Recency: Number of days since customer's last purchase
# <br>
# Complain: 1 if customer complained in the last 2 years, 0 otherwise
# <br>
#
# **Products**
# <br>
# MntWines: Amount spent on wine in last 2 years
# <br>
# MntFruits: Amount spent on fruits in last 2 years
# <br>
# MntMeatProducts: Amount spent on meat in last 2 years
# <br>
# MntFishProducts: Amount spent on fish in last 2 years
# <br>
# MntSweetProducts: Amount spent on sweets in last 2 years
# <br>
# MntGoldProds: Amount spent on gold in last 2 years
# <br>
#
# **Promotion**
# <br>
# NumDealsPurchases: Number of purchases made with a discount
# <br>
# AcceptedCmp1: 1 if customer accepted the offer in the 1st campaign, 0 otherwise
# <br>
# AcceptedCmp2: 1 if customer accepted the offer in the 2nd campaign, 0 otherwise
# <br>
# AcceptedCmp3: 1 if customer accepted the offer in the 3rd campaign, 0 otherwise
# <br>
# AcceptedCmp4: 1 if customer accepted the offer in the 4th campaign, 0 otherwise
# <br>
# AcceptedCmp5: 1 if customer accepted the offer in the 5th campaign, 0 otherwise
# <br>
#
#
# **Place**
# <br>
# NumWebPurchases: Number of purchases made through the company’s web site
# <br>
# NumCatalogPurchases: Number of purchases made using a catalogue
# <br>
# NumStorePurchases: Number of purchases made directly in stores
# <br>
# NumWebVisitsMonth: Number of visits to company’s web site in the last month
#
#
# Dataset credits go to Kaggle user Akash Patel https://www.kaggle.com/imakash3011/customer-personality-analysis
#
# * Load the dataset, check all column types and check for missing values. Drop rows with missing values in the Education column.
#
# * Create a smaller dataset consisting of households where the MntWines variable is lower than 160 and where MntMeatProducts is higher than 40.
#
# * What is the mean number of teenagers in these households in your smaller dataset?
#
# * What are the most and least common education levels in your smaller dataset?

# %%
import pandas as pd
#I make sure to specify the separator, otherwise the dataset cannot be worked with
marketing = pd.read_csv("marketing_campaign.csv", sep=';')

#I check for column types
marketing.dtypes

#I check for NAs
marketing.isna().sum()

#To createa smaller dataset I do:
marketing_smaller = marketing[(marketing['MntWines'] < 160) & (marketing['MntMeatProducts'] > 40)]

#however before doing that I once again check the output for .dtypes to see if these are int or int64 columns
#if so, I can operate on them with mathematical operators

# %%
len(marketing_smaller)
# Out:
# 217

# %%
marketing_smaller
# Out:
#       customer_id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 7            6177        1985         PhD        Married  33454.0        1
# 20           9360        1982  Graduation        Married  37040.0        0
# 21           5376        1979  Graduation        Married   2447.0        1
# 28           9422        1989  Graduation        Married  38360.0        1
# 31           3033        1963      Master       Together  38620.0        0
# ...           ...         ...         ...            ...      ...      ...
# 2159        10157        1965  Graduation         Single  59686.0        0
# 2179         4541        1955  Graduation       Together  38946.0        0
# 2196         1839        1974  Graduation         Single  43322.0        0
# 2228         8720        1978    2n Cycle       Together      NaN        0
# 2239         9405        1954         PhD        Married  52869.0        1
#
# ...

# %% [markdown]
# The length and remaining data in marketing_smaller shows that my filtering/subsetting worked.

# %%
#to check the mean number of teenagers i first need to know the column names
marketing_smaller.columns
#I also take a look at the column and again confirm that it is int or in64
marketing_smaller['Teenhome']
marketing_smaller.dtypes
#then I check the mean with .mean()
marketing_smaller['Teenhome'].mean()
# Out:
# 0.4377880184331797

# %%
marketing_smaller.columns
#Since I'm only checking value counts, which I can do with ints, strings and objects, I don't need to check column types
marketing_smaller['Education'].value_counts()
# Out:
# Graduation    121
# PhD            35
# Master         35
# 2n Cycle       25
# Basic           1
# Name: Education, dtype: int64

# %% [markdown]
# The most common education type is Graduation while the least common education type is Basic

# %% [markdown]
# # Challenge 2
#
# The dataset marketing_campaign_response.csv contains an additional observation - whether each customer did or did not respond to the marketing campaign (a binary variable with values 0 and 1). The variable is coded 1 if a customer accepted the offer in the last campaign, 0 otherwise.
#
# * Use the appropriate join (left, right, inner, outer) to merge the dataset created in Challenge 1 with marketing_campaign_response.csv, such that all observations from both datasets are included. <br>  **Note: the identifier column names differ across the two datasets.**  <br> Make sure to reflect on the differences in size (or observations included) between the dataset form Challenge 1, the *marketing_campaign_response* dataset and the merged dataset.  <br> *Hint: The lenght of the merged dataset will depend on the type of merge you will have chosen.*
#
# * Use the appropriate join (left, right, inner, outer) to merge marketing_campaign.csv with marketing_campaign_response.csv, such that only those observations included in marketing_campaign_response.csv are included.
#
# * Drop rows with missing values in any column in the final merged dataset.

# %%
#As before, having tried to load the dataset without a separator argument, I see that the columns are not formatted well
#I input the appropriate sep argument
responses = pd.read_csv("marketing_campaign_response.csv", sep =';')

#I check che column names before I merge
responses.columns
# Out:
# Index(['ID', 'Response'], dtype='object')

# %%
marketing_smaller.columns
# Out:
# Index(['customer_id', 'Year_Birth', 'Education', 'Marital_Status', 'Income',
#        'Kidhome', 'Teenhome', 'Dt_Customer', 'Recency', 'MntWines',
#        'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue'],
#       dtype='object')

# %%
#In the responses, the id columns is called ID, so I merge left_on ID and right_on customer_id (for marketing_smaller)
inner_data = pd.merge(responses, marketing_smaller, how='inner', left_on="ID", right_on="customer_id")
# Out:
#         ID  Response  customer_id  Year_Birth   Education Marital_Status  \
# 0     6177       0.0         6177        1985         PhD        Married
# 1     9360       0.0         9360        1982  Graduation        Married
# 2     5376       0.0         5376        1979  Graduation        Married
# 3     9422       0.0         9422        1989  Graduation        Married
# 4     3033       0.0         3033        1963      Master       Together
# ..     ...       ...          ...         ...         ...            ...
# 206  10157       0.0        10157        1965  Graduation         Single
# 207   4541       0.0         4541        1955  Graduation       Together
# 208   1839       0.0         1839        1974  Graduation         Single
# 209   8720       0.0         8720        1978    2n Cycle       Together
# 210   9405       1.0         9405        1954         PhD        Married
#
#       Income  Kidhome  Teenhome Dt_Customer  ...  NumStorePurchases  \
# ...

# %%
#I check the various df sizes as follows
len(inner_data)
# Out:
# 211

# %%
len(marketing_smaller)
# Out:
# 217

# %%
len(responses)
# Out:
# 2174

# %% [markdown]
# As expected, the inner merged dataset is the smallest.

# %%
responses_prioritized = pd.merge(marketing_smaller, responses, how='right', left_on="customer_id", right_on="ID")
len(responses_prioritized)
# Out:
# 2174

# %% [markdown]
# As expected, the join that prioritized the responses dataset (responses_prioritized) has exactly the same number of rows as the initial responses dataset.

# %%
#I check NAs with 
responses_prioritized.isna().sum()
# Out:
# customer_id            1963
# Year_Birth             1963
# Education              1963
# Marital_Status         1963
# Income                 1967
# Kidhome                1963
# Teenhome               1963
# Dt_Customer            1963
# Recency                1963
# MntWines               1963
# MntFruits              1963
# MntMeatProducts        1963
# MntFishProducts        1963
# MntSweetProducts       1963
# MntGoldProds           1963
# NumDealsPurchases      1963
# NumWebPurchases        1963
# NumCatalogPurchases    1963
# NumStorePurchases      1963
# NumWebVisitsMonth      1963
# AcceptedCmp3           1963
# AcceptedCmp4           1963
# AcceptedCmp5           1963
# AcceptedCmp1           1963
# AcceptedCmp2           1963
# Complain               1963
# Z_CostContact          1963
# Z_Revenue              1963
# ID                        0
# Response                  1
# dtype: int64

# %%
#I drop all columns with any NAs as follows, leaving me with a dataset with 206 rows, far less than the initial dataset. 
#This is due to the many NAs generated by prioritizing the right dataset, while executing the merge (since the left dataset is much smaller)
responses_prioritized.dropna(how='any', inplace=True)
responses_prioritized
# Out:
#       customer_id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 7          6177.0      1985.0         PhD        Married  33454.0      1.0
# 20         9360.0      1982.0  Graduation        Married  37040.0      0.0
# 21         5376.0      1979.0  Graduation        Married   2447.0      1.0
# 28         9422.0      1989.0  Graduation        Married  38360.0      1.0
# 31         3033.0      1963.0      Master       Together  38620.0      0.0
# ...           ...         ...         ...            ...      ...      ...
# 2090       8726.0      1964.0    2n Cycle       Divorced  41713.0      1.0
# 2093      10157.0      1965.0  Graduation         Single  59686.0      0.0
# 2113       4541.0      1955.0  Graduation       Together  38946.0      0.0
# 2130       1839.0      1974.0  Graduation         Single  43322.0      0.0
# 2173       9405.0      1954.0         PhD        Married  52869.0      1.0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  AcceptedCmp3  \
# ...

# %% [markdown]
# # Challenge 3
#
# * Determine what percentage of the customers from the final dataset from Challenge 2 accepted the offer.
#
# * Determine the average income for each combination of education level and marital status for customers from the final dataset from Challenge 2. Make sure to use the methods to group the dataset shown in class to make your code efficient.
#
# * Create a new column called NumKids which denotes the total number of children (kids and teens) in the household for customers from the latest dataset. <br> *Hint: Pandas makes it easy to run numerical operations across columns. Let's say that I want to multiply the value that is in column A by the value that is in column B and store it in column C... I can simply use: `df['C'] = df['A'] * df['B']`*
#
# * Write a csv file (using pandas) with the dataset from excercise 3.

# %%
#dropping NAs (a good practice), and normalizing the value counts to get percentages is one way to solve this challenge
responses_prioritized['Response'].value_counts(dropna=False, normalize=True)
# ~83% of those targetted did not accept the offer
# Out:
# 0.0    0.834951
# 1.0    0.165049
# Name: Response, dtype: float64

# %%
responses_prioritized.columns
# Out:
# Index(['customer_id', 'Year_Birth', 'Education', 'Marital_Status', 'Income',
#        'Kidhome', 'Teenhome', 'Dt_Customer', 'Recency', 'MntWines',
#        'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'ID',
#        'Response'],
#       dtype='object')

# %%
#To determine average income for education and marital status combinations I use groupby and .mean()
responses_prioritized.groupby(['Education', 'Marital_Status'])['Income'].mean()
# Out:
# Education   Marital_Status
# 2n Cycle    Divorced          41713.000000
#             Married           50100.363636
#             Single            43991.000000
#             Together          33175.500000
#             Widow             28457.000000
# Basic       Married           26997.000000
# Graduation  Divorced          61422.750000
#             Married           45227.583333
#             Single            41555.375000
#             Together          49377.080000
#             Widow             36200.333333
# Master      Divorced          50247.571429
#             Married           48527.000000
#             Single            32387.000000
#             Together          48554.285714
#             Widow             33051.000000
# PhD         Divorced          49623.250000
#             Married           52917.875000
#             Single            43170.200000
#             Together          48394.666667
#             Widow             78028.000000
# ...

# %%
#To create a new column, I do as follows: 
responses_prioritized['Total Kids No.'] = responses_prioritized['Kidhome'] + responses_prioritized['Teenhome']
# I additionally generate a quick summary of output for the column with .describe()
responses_prioritized['Total Kids No.'].describe()
# Out:
# count    206.000000
# mean       0.970874
# std        0.711663
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        3.000000
# Name: Total Kids No., dtype: float64

# %%
responses_prioritized.to_csv("my_first_csv.csv")
