# %% [markdown]
# # Challenges week 6
#
# Now that you have some experience with working with APIs and playing around with this data, it's time for you to combine and apply your knowledge. You will start working on these challenges in the tutorial and will be asked to complete them by the end of the week.
#
# In each challenge, you are asked to provide the programing solution to it as well as a technical interpretation explaining the steps taken and the result.
#
# Some important notes for the challenges:
#
# * If you get an error message, try to troubleshoot it (using Google often helps). If all else fails, go to the next excercise (but make sure to hand it in).
# * We will make sure to provide feedback and improvement suggestions in the rubric. Make sure to read them; they will help you improve next week.

# %% [markdown]
# # Challange 1
#
# Here is a list of easy to use APIs related to enterntainment https://github.com/public-apis/public-apis#entertainment with little or no authentication. We will now use the RandomUselessFacts API, for which the documentation is very simple and can be found here https://uselessfacts.jsph.pl/.
# 1. Interact with the API to get access to a random fact or the fact of the day.
# 2. Write a function that builds upon your initial script and allows for increased functionality/interaction with the API. The most obvious option here is to write a function that allows you to collect many facts in a neat fashion using the /random endpoint. For the function, provide the necessary code and a short explanation of the working of the function.

# %%
import requests 

a_fact = requests.get('https://uselessfacts.jsph.pl/today.json')
a_fact
#I get the appropriate response code

# %%
#Here's the content
a_fact.content

# %%
#A function that retrieves thrity random facts
fact_list = []
def get_a_fact():
    for i in range(1,30):
        a_fact =requests.get('https://uselessfacts.jsph.pl/random.json?language=en')
        fact_list.append(a_fact.content)
        return fact_list
my_facts = get_a_fact()
my_facts

# %% [markdown]
# # Challenge 2
#
# 1. Look through the list of APIs above and write a script to interact with an API of your choosing. Write a script to interact with this API using the requests library and the GET method (make sure to consult the API documentation to make the code work) to retrieve at least 20 observations/rows into a dataframe from the json file response provided by the API. Provide the necessary code and a short explanation of the working of it (what happens at different steps).
#
# 2.  Explore the dataset using the skills learned in previous weeks including essential steps such as checking column names or dict keys, data types, missing values and looking at relevant descriptive statistics. Based on it write a short summary about the dataset. <br>*Tip: not all steps such as merging or selecting relevant columns are necessary, but make sure to explore how dataset looks like, its columns and data types, missing data, and descriptive statistics).*
#
# 3. Make sure that the API chosen allows for data that can generate one simply visualisation based on one or two variables (e.g. a bar chart, line plot, scatterplot). Generate this visualisation. Justify your choice for the visualisation type. <br> *Tip: when choosing a visualisation, think about measurement level of your variables.*

# %%
#No custom solution can be provided

# %% [markdown]
# # Challenge 3
#
# The dataset `example_tweets.json` is the json  response returned from the Twitter API. This is a data collected using the keyword search surveillance - tweets that include this keyword are included in the dataset. On [this website](https://developer.twitter.com/en/docs/twitter-api/v1/data-dictionary/object-model/tweet) you can find the documentation of the API and the columns it returns. In this challenge, you will explore this data and identify possible privacy and ethical issues with it.
#
#
# 1. Use pandas to load this data into a dataframe.
#
# 2. Explore this dataset and variables using the skills you have learned in the class. Make sure to check how the dataset looks like, what columns it has, what data type these columns have and if there are any missing values. Write a short descritpion of the dataset and answer the following questions:
# * How many languages are the tweets in?
# * How many retweets did the tweets recieve on average?
# * Is the retweets number higher or lower for tweets that contain sensitive links vs. the one's with non-sensitive and no links? *Tip: check in the documentation what missing values in column `possibly_sensitive` mean and consider what you need to do with them.*
#
# 3. Imagine that you want to research if there is a relation between the topics in the text of the tweets about surveillance and number of retweets the tweets recieve. You want to include number of followers of the author of each tweet as a control variable. Hence, you need the columns with information on the text of the tweet (`text`), its number of retweets (`retweet_count`) and the number of followers of the author (included in `user`).
# * Minimize the dataset accordingly. Explain your minimization steps.
# * What other steps would you need to take to make sure that the data follows privacy protection principles discussed in the lecture? Give concrete examples based on the information available in your minimized dataset. *Tip: consider what identifiable and identified information the text and user columns contain.*

# %%
#load the data
import pandas as pd
data = pd.read_json("example_tweets.json")

# %%
data.dtypes
# Out:
# created_at                   datetime64[ns]
# id                                    int64
# id_str                                int64
# full_text                            object
# truncated                              bool
# display_text_range                   object
# entities                             object
# metadata                             object
# source                               object
# in_reply_to_status_id               float64
# in_reply_to_status_id_str           float64
# in_reply_to_user_id                 float64
# in_reply_to_user_id_str             float64
# in_reply_to_screen_name              object
# user                                 object
# geo                                 float64
# coordinates                         float64
# place                                object
# contributors                        float64
# retweeted_status                     object
# is_quote_status                        bool
# quoted_status_id                    float64
# quoted_status_id_str                float64
# retweet_count                         int64
# favorite_count                        int64
# favorited                              bool
# retweeted                              bool
# lang                                 object
# quoted_status                        object
# possibly_sensitive                  float64
# extended_entities                    object
# withheld_in_countries                object
# dtype: object

# %%
data.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'full_text', 'truncated',
#        'display_text_range', 'entities', 'metadata', 'source',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'retweeted_status', 'is_quote_status',
#        'quoted_status_id', 'quoted_status_id_str', 'retweet_count',
#        'favorite_count', 'favorited', 'retweeted', 'lang', 'quoted_status',
#        'possibly_sensitive', 'extended_entities', 'withheld_in_countries'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# created_at                      0
# id                              0
# id_str                          0
# full_text                       0
# truncated                       0
# display_text_range              0
# entities                        0
# metadata                        0
# source                          0
# in_reply_to_status_id         885
# in_reply_to_status_id_str     885
# in_reply_to_user_id           882
# in_reply_to_user_id_str       882
# in_reply_to_screen_name       882
# user                            0
# geo                          1000
# coordinates                  1000
# place                         994
# contributors                 1000
# retweeted_status              289
# is_quote_status                 0
# quoted_status_id              920
# quoted_status_id_str          920
# retweet_count                   0
# favorite_count                  0
# favorited                       0
# retweeted                       0
# lang                            0
# quoted_status                 983
# possibly_sensitive            777
# extended_entities             911
# withheld_in_countries         999
# dtype: int64

# %%
data
# Out:
#              created_at                   id               id_str  \
# 0   2021-09-12 15:08:10  1437070537428066307  1437070537428066304
# 1   2021-09-11 21:32:49  1436804949502013442  1436804949502013440
# 2   2021-09-13 15:52:10  1437444000403759106  1437444000403759104
# 3   2021-09-12 16:18:28  1437088228251635714  1437088228251635712
# 4   2021-09-11 13:28:13  1436682997420417030  1436682997420417024
# ..                  ...                  ...                  ...
# 995 2021-09-11 18:45:26  1436762828149493766  1436762828149493760
# 996 2021-09-15 22:12:23  1438264459458486275  1438264459458486272
# 997 2021-09-13 19:11:25  1437494140737052674  1437494140737052672
# 998 2021-09-12 07:50:34  1436960411425910785  1436960411425910784
# 999 2021-09-14 02:34:49  1437605727129030660  1437605727129030656
#
#                                              full_text  truncated  \
# 0    RT @AP: BREAKING: Iran says it will allow UN t...      False
# 1    RT @emeriticus: Bush launched murderous wars f...      False
# 2    RT @scroll_in: #PegasusRow \n\nCentre refuses ...      False
# 3    @mararara44 @JudahWorldChamp @kprather88 @CDCg...      False
# 4                @CoinMarketCap financial surveillance      False
# ..                                                 ...        ...
# 995  RT @FrommerRob: This kind of dragnet search wi...      False
# 996  RT @stacydavisgates: “The delays in contact tr...      False
# 997  RT @AnnaNosthoff: Our talk @werkleitz about Bi...      False
# 998  China’s tech workers pushed to their limits by...      False
# 999  RT @NDGcrypto: @AdrianStarr108 @akashnet_ @gre...      False
#
#     display_text_range                                           entities  \
# 0             [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1             [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2             [0, 139]  {'hashtags': [{'text': 'PegasusRow', 'indices'...
# 3           [104, 384]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4             [15, 37]  {'hashtags': [], 'symbols': [], 'user_mentions...
# ..                 ...                                                ...
# 995           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 996           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 997           [0, 144]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 998           [0, 102]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 999           [0, 140]  {'hashtags': [], 'symbols': [{'text': 'AKT', '...
#
#                                               metadata  \
# 0    {'iso_language_code': 'en', 'result_type': 're...
# 1    {'iso_language_code': 'en', 'result_type': 're...
# 2    {'iso_language_code': 'en', 'result_type': 're...
# 3    {'iso_language_code': 'en', 'result_type': 're...
# 4    {'iso_language_code': 'fr', 'result_type': 're...
# ..                                                 ...
# 995  {'iso_language_code': 'en', 'result_type': 're...
# 996  {'iso_language_code': 'en', 'result_type': 're...
# 997  {'iso_language_code': 'en', 'result_type': 're...
# 998  {'iso_language_code': 'en', 'result_type': 're...
# 999  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                 source  in_reply_to_status_id  \
# 0    <a href="http://twitter.com/download/android" ...                    NaN
# 1    <a href="http://twitter.com/download/iphone" r...                    NaN
# 2    <a href="http://twitter.com/download/android" ...                    NaN
# 3    <a href="http://twitter.com/#!/download/ipad" ...           1.437050e+18
# 4    <a href="https://mobile.twitter.com" rel="nofo...           1.436682e+18
# ..                                                 ...                    ...
# 995  <a href="http://twitter.com/download/iphone" r...                    NaN
# 996  <a href="http://twitter.com/download/iphone" r...                    NaN
# 997  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 998  <a href="http://twitter.com/download/android" ...                    NaN
# 999  <a href="http://twitter.com/download/iphone" r...                    NaN
#
#      ...  quoted_status_id_str  retweet_count  favorite_count favorited  \
# 0    ...                   NaN            100               0     False
# 1    ...                   NaN            298               0     False
# 2    ...                   NaN              1               0     False
# 3    ...                   NaN              0               0     False
# 4    ...                   NaN              0               2     False
# ..   ...                   ...            ...             ...       ...
# 995  ...          1.436722e+18              2               0     False
# 996  ...                   NaN             20               0     False
# 997  ...                   NaN             12               0     False
# 998  ...                   NaN              1               0     False
# 999  ...                   NaN             17               0     False
#
#     retweeted  lang  quoted_status possibly_sensitive  extended_entities  \
# 0       False    en           None                NaN               None
# 1       False    en           None                NaN               None
# 2       False    en           None                NaN               None
# 3       False    en           None                NaN               None
# 4       False    fr           None                NaN               None
# ..        ...   ...            ...                ...                ...
# 995     False    en           None                NaN               None
# 996     False    en           None                NaN               None
# 997     False    en           None                NaN               None
# 998     False    en           None                0.0               None
# 999     False    en           None                NaN               None
#
#     withheld_in_countries
# 0                    None
# 1                    None
# 2                    None
# 3                    None
# 4                    None
# ..                    ...
# 995                  None
# 996                  None
# 997                  None
# 998                  None
# 999                  None
#
# [1000 rows x 32 columns]

# %% [markdown]
# After examining the dataset, I can conclude that it has 1000 rows with 32 columns, including created_at, id, etc. Some columsn have many missing values (800+). However, the columns we are interested in can be worked with and are of the expected variable type.

# %%
#how many languages
data['lang'].value_counts()
#English is the dominant language of the tweets, with tweets available in 13 languages.
# Out:
# en     832
# fr     109
# ca      25
# nl      11
# und      7
# es       3
# it       3
# tl       2
# in       2
# de       2
# ja       2
# hi       1
# th       1
# Name: lang, dtype: int64

# %%
#avg retweets 
data['retweet_count'].mean()
#the mean rt count is 417,352
# Out:
# 417.352

# %%
smaller_data = data[['full_text', 'retweet_count', 'user']]
smaller_data
# Out:
#                                              full_text  retweet_count  \
# 0    RT @AP: BREAKING: Iran says it will allow UN t...            100
# 1    RT @emeriticus: Bush launched murderous wars f...            298
# 2    RT @scroll_in: #PegasusRow \n\nCentre refuses ...              1
# 3    @mararara44 @JudahWorldChamp @kprather88 @CDCg...              0
# 4                @CoinMarketCap financial surveillance              0
# ..                                                 ...            ...
# 995  RT @FrommerRob: This kind of dragnet search wi...              2
# 996  RT @stacydavisgates: “The delays in contact tr...             20
# 997  RT @AnnaNosthoff: Our talk @werkleitz about Bi...             12
# 998  China’s tech workers pushed to their limits by...              1
# 999  RT @NDGcrypto: @AdrianStarr108 @akashnet_ @gre...             17
#
#                                                   user
# 0    {'id': 3264870655, 'id_str': '3264870655', 'na...
# 1    {'id': 1357150919192944640, 'id_str': '1357150...
# 2    {'id': 1124167148, 'id_str': '1124167148', 'na...
# 3    {'id': 15497992, 'id_str': '15497992', 'name':...
# 4    {'id': 177506855, 'id_str': '177506855', 'name...
# ..                                                 ...
# 995  {'id': 114094989, 'id_str': '114094989', 'name...
# 996  {'id': 339340704, 'id_str': '339340704', 'name...
# 997  {'id': 548575737, 'id_str': '548575737', 'name...
# 998  {'id': 1050029231823118338, 'id_str': '1050029...
# 999  {'id': 1277297040410783745, 'id_str': '1277297...
#
# [1000 rows x 3 columns]

# %% [markdown]
# If we were to share this data, we would have to be careful with the user id and text columns since both can contain identifying information both for the poster and for other Twitter users which may or may not be in our dataset.
